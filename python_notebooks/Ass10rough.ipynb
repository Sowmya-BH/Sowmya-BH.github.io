# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import ipywidgets

# %%
bf = pd.read_csv("https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv",parse_dates = ["date"])
bf.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# ...

# %%
bf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4747 entries, 0 to 4746
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   observed            4711 non-null   object
#  1   location_details    4009 non-null   object
#  2   county              4747 non-null   object
#  3   state               4747 non-null   object
#  4   season              4747 non-null   object
#  5   title               3797 non-null   object
#  6   latitude            3797 non-null   float64
#  7   longitude           3797 non-null   float64
#  8   date                3797 non-null   datetime64[ns]
#  9   number              4747 non-null   float64
#  10  classification      4747 non-null   object
#  11  geohash             3797 non-null   object
#  12  temperature_high    3098 non-null   float64
#  13  temperature_mid     2950 non-null   float64
#  14  temperature_low     2953 non-null   float64
# ...

# %%
bf["Year_of_incidence"] = bf["date"].dt.year
bf.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# ...

# %%
bf["Year_of_incidence"].value_counts()
# Out:
# 2004.0    241
# 2005.0    210
# 2006.0    175
# 2003.0    149
# 2007.0    142
#          ...
# 1921.0      1
# 1941.0      1
# 1954.0      1
# 1925.0      1
# 1937.0      1
# Name: Year_of_incidence, Length: 80, dtype: int64

# %%
chart31 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"},
  "mark":"point",
  "height":400,
  "width":800,
  "encoding":{
    "x":{"field":"state", "type":"nominal"},
    "y":{"field":"temperature_mid","type":"quantitative"},
    "color":{"field":"classification","type":"nominal"}
  }# end encoding
});
#var v = vegaEmbed("#preciptPlot",myPreciptSpec)
chart31
# Out:
# alt.Chart(...)

# %%
chart32 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"},
  "mark":"bar",
  "height":400,
  "width":800,
  "encoding":{
    "x":{"field":"state","type":"nominal"},
    "y":{"field":"number","aggregate": "sum","type":"quantitative",},
    "color":{"field":"classification","type":"nominal"}
  }# end encoding
});
#var v = vegaEmbed("#preciptPlot",myPreciptSpec)
chart32
# Out:
# alt.Chart(...)

# %%
chart = alt.VConcatChart(vconcat=[chart31,chart32])
chart
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Adding interactivity with a brush selector

# %%
brush = alt.selection_interval(encodings=['x','y'])

# %%
chart31.add_selection(
    brush
)
# Out:
# alt.Chart(...)

# %%
chart41 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"},
  "mark":"point",
  "height":400,
  "width":800,
  "encoding":{
    "x":{"field":"state", "type":"nominal"},
    "y":{"field":"temperature_mid","type":"quantitative"},
    "color":{"field":"classification","type":"nominal"}
  }# end encoding
}).add_selection(
    brush
);

chart41
# Out:
# alt.Chart(...)

# %% [markdown]
# **Here I created a scatter plot to explore the relationship between temperature and state, by taking the mid temperature for each state on the y-axis and the state name on the x-axis.**

# %%
chart42 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"},
  "mark":"bar",
  "height":400,
  "width":800,
  "encoding":{
    "x":{"field":"state","type":"nominal"},
    "y":{"field":"number","aggregate": "sum","type":"quantitative",},
    "color":{"field":"classification","type":"nominal"}
  }# end encoding
})

chart42
# Out:
# alt.Chart(...)

# %% [markdown]
# **Here I plotted the number of Bigfoot sightings in each state , by passing the state variable to the x-axis and aggregate of sightings on the y-axis.Additionally,I used the color-coding to provide additional information about the type of classification. The number of sightings are the greatest in the state of Washington followed by Illinois and Florida.**

# %%
chart32.transform_filter(
    brush
)
# Out:
# alt.Chart(...)

# %%
chart42 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"},
  "mark":"bar",
  "height":400,
  "width":800,
  "encoding":{
    "x":{"field":"state","type":"nominal"},
    "y":{"field":"number","aggregate": "sum","type":"quantitative",},
    "color":{"field":"classification","type":"nominal"}
  }# end encoding
}).transform_filter(
    brush
);
#var v = vegaEmbed("#preciptPlot",myPreciptSpec)
chart42
# Out:
# alt.Chart(...)

# %%
chart = chart41 & chart42
chart
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# **Here I plotted the number of Bigfoot sightings in each state , by passing the state variable to the x-axis and aggregate of sightings on the y-axis.Additionally,I used the color-coding to provide additional information about the type of classification. The number of sightings are the greatest in the state of Washington followed by Illinois and Florida.**

# %%
chartCholoro = alt.Chart.from_dict({
  "data": {
    "url": "https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv",
    "format": {"type": "csv"}
  },
  "projection": {"type": "albersUsa"},
  "mark": "geoshape",
  "encoding": {
    "color": {
      "field": "average_temperature",
      "type": "quantitative",
#      "scale": {"type": "linear", "scheme": "viridis"}
    },
      "transform": [{
    "lookup": "id",
    "from": {
      "data": {
        "url": "https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv"
      },
   #   "key": "id",
      "fields": ["state"]
    }
  }],
    "tooltip": [
      {"field": "state", "type": "nominal"},
      {"field": "average_temperature", "type": "quantitative"}
    ]
  }
});
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /var/folders/jj/d614s3c100q03b2wqqj605dw0000gn/T/ipykernel_27472/72050345.py in <module>
#      24     "tooltip": [
#      25       {"field": "state", "type": "nominal"},
# ---> 26       {"field": "average_temperature", "type": "quantitative"}
#      27     ]
#      28   }
#
# ~/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/altair/vegalite/v4/api.py in from_dict(cls, dct, validate)
#    2007
#    2008         # As a last resort, try using the Root vegalite object
# -> 2009         return core.Root.from_dict(dct, validate)
#    2010
#    2011     def to_dict(self, *args, **kwargs):
#
# ~/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/altair/utils/schemapi.py in from_dict(cls, dct, validate, _wrapper_classes)
#     405         """
#     406         if validate:
# --> 407             cls.validate(dct)
# ...

# %%
chartCholoro = alt.Chart.from_dict({
  "data": {
    "url": "https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv",
    "format": {"type": "csv"}
  },
  
  "projection": {"type": "albersUsa"},
  "mark": "geoshape",
  "encoding": {
    "color": {
      "field": "average_temperature",
      "type": "quantitative",
      "scale": {"type": "linear", "scheme": "viridis"}
    },
    "tooltip": [
      {"field": "state", "type": "nominal"},
      {"field": "average_temperature", "type": "quantitative"}
    ]
  }
}),


chartCholoro
# Out:
# alt.Chart(...)

# %%
chartCholoro
# Out:
# alt.Chart(...)

# %%
chartCholoroN = alt.Chart.from_dict({
"data": {
    "url": "data/us-10m.json",
    "format": {
      "type": "topojson",
      "feature": "counties"
    }
  },
  "transform": [{
    "lookup": "index",
    "from": {
      "data": {
        "url": "https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/bfro_reports_fall2022.csv",
        "format": {"type": "csv"}
      },
      "key": "index",
      "fields": ["county"]
    }
  }],
  "projection": {"type": "albersUsa"},
  "mark": "geoshape",
  "encoding": {
    "color": {
      "field": "average_temperature",
      "type": "quantitative",
      #"scale": {"type": "linear", "scheme": "viridis"}
    },
    "tooltip": [
      {"field": "county", "type": "nominal"},
      {"field": "average_temperature", "type": "quantitative"}
    ]
  }
})

# %%
chartCholoroN
# Out:
# alt.Chart(...)

# %%
Dashboard.save(DataViz+"BigFootSightingsState.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jj/d614s3c100q03b2wqqj605dw0000gn/T/ipykernel_27472/579231262.py in <module>
# ----> 1 Dashboard.save(DataViz+"BigFootSightingsState.json")
#
# NameError: name 'DataViz' is not defined
